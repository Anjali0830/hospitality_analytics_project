# %%
# !pip install seaborn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Load cleaned data
df = pd.read_csv( r"E:\Hospitality_Analytics_Project\data\processed\cleaned_hotel_booking_dataset.csv")


#1. Cancellation Rate
sns.countplot(
    x='is_canceled',
    data=df
)

plt.show()


#2. Lead Time vs Cancellation
sns.boxplot(
    x='is_canceled',
    y='lead_time',
    data=df
)

plt.show()


#3. ADR vs Cancellation
sns.boxplot(
    x='is_canceled',
    y='adr',
    data=df
)

plt.show()


#4. Market Segment Analysis
df['market_segment'].value_counts()
sns.countplot(
    y='market_segment',
    data=df
)

plt.show()


#5. Country Analysis
df['country'].value_counts().head(10)


#6. Monthly Booking Trend
sns.countplot(
    x='arrival_date_month',
    data=df
)

plt.xticks(rotation=90)

plt.show()


#7. Correlation Heatmap
sns.heatmap(
    df.corr(numeric_only=True)
)

plt.show()

print("Exploratory Data Analysis completed successfully.")
# Out:
# Requirement already satisfied: seaborn in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Anjali Gurav\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
