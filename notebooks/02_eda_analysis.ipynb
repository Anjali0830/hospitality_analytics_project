# %%
# !pip install seaborn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Load cleaned data
df = pd.read_csv( r"E:\Hospitality_Analytics_Project\data\processed\cleaned_hotel_booking_dataset.csv")
